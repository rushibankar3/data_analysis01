# %% [markdown]
# <a href="https://colab.research.google.com/github/rushibankar3/data_analysis01/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/kohli.csv')

# %%
print("Column names:", df.columns.tolist())
# Out:
# Column names: ['Date', 'Match', 'BO', 'Run', 'Boundary', 'SR', 'Out']

# %%
df.head()
# Out:
#        Date       Match  BO        Run Boundary    SR      Out
# 0  09/03/25   IND vs NZ   3      1 (2)      0/0  50.0      lbw
# 1  04/03/25  IND vs AUS   3    84 (98)      5/0  85.7    catch
# 2  02/03/25   IND vs NZ   3    11 (14)      2/0  78.5    catch
# 3  23/02/25  IND vs PAK   3  100 (111)      7/0  90.0  not out
# 4  20/02/25  IND vs BAN   3    22 (38)      1/0  57.8    catch

# %%
df.describe()
# Out:
#                BO          SR
# count  300.000000  299.000000
# mean     3.186667   80.861639
# std      0.678249   35.330219
# min      1.000000    0.000000
# 25%      3.000000   64.050000
# 50%      3.000000   82.900000
# 75%      3.000000  100.000000
# max      7.000000  209.000000

# %%
df.isnull().sum()
# Out:
# Date        0
# Match       0
# BO          0
# Run         0
# Boundary    0
# SR          1
# Out         1
# dtype: int64

# %%
print("Data types:\n", df.dtypes)
# Out:
# Data types:
#  Date         object
# Match        object
# BO            int64
# Run          object
# Boundary     object
# SR          float64
# Out          object
# dtype: object

# %%
print(df.shape)
print(df.info())
# Out:
# (300, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      300 non-null    object
#  1   Match     300 non-null    object
#  2   BO        300 non-null    int64
#  3   Run       300 non-null    object
#  4   Boundary  300 non-null    object
#  5   SR        299 non-null    float64
#  6   Out       299 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 16.5+ KB
# None

# %%
sns.countplot(df['Out'])
# Out:
# <Axes: xlabel='count', ylabel='Out'>

# %%
plt.hist(df['Run'],bins=5)
# Out:
# (array([68., 59., 62., 54., 57.]),
#  array([  0. ,  53.6, 107.2, 160.8, 214.4, 268. ]),
#  <BarContainer object of 5 artists>)
